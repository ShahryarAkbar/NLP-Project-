# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahryarAkbar/NLP-Project-/blob/main/dialogue_generated_practice_by_gpt_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 56.1 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "gpt2" 
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# %%
input_text = "are you friends with"
input_ids = tokenizer.encode(input_text, return_tensors='pt')

# %%
import torch
output_ids = model.generate(
    input_ids,
    max_length=500,
    do_sample=True,
    top_p=0.92,
    temperature=0.85,
    pad_token_id=tokenizer.eos_token_id, #padding token ID
    attention_mask=torch.ones(input_ids.shape, dtype=torch.long) # attention mask setting
)

# %%
output_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print(output_text)
# Out:
# are you friends with a good drink?"
#
# "You're the only one in here," she said, looking up at him, her eyes on the table.
#
# "I know, I know!" he said, looking at her. "So you're going to say that if you don't tell me about them, I'll shut up. I'm going to stop your whole thing and just tell you. What you've done to me is wrong, and it's time I told you about it, so I can tell you how things have gotten worse over the years."
#
# ...
